# %% [markdown]
# # Arbeitspaket (AP) 3: Management & Nutzung Räumliche Daten

# %% [markdown]
# ### Angaben Studierende(r) (fehlende Angaben ergänzen)

# %% [markdown]
# <table>
#   <tr>
#     <td>Vorname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Nachname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Immatrikulationsnummer:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Modul:</td>
#     <td>Data Science</td>
#   </tr>
#   <tr>
#     <td>Prüfungsdatum / Raum / Zeit:</td>
#     <td>07.10.2024 / Raum: SF O3.54 / 8:00 – 11:45</td>
#   </tr>
#   <tr>
#     <td>Erlaubte Hilfsmittel:</td>
#     <td>w.MA.XX.DS.24HS (Data Science)<br>Open Book, Eigener Computer, Internet-Zugang</td>
#   </tr>
#   <tr>
#   <td>Nicht erlaubt:</td>
#   <td>Nicht erlaubt ist der Einsatz beliebiger Formen von generativer KI (z.B. Copilot, ChatGPT) <br> sowie beliebige Formen von Kommunikation oder Kollaboration mit anderen Menschen.</td>
# </tr>
# </table>

# %% [markdown]
# ## Bewertungskriterien
#
# ### <b style="color: gray;">(max. erreichbare Punkte: 48)</b>
#
# <table>
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Beschreibung</th>
#       <th>Punkteverteilung</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Code nicht lauffähig oder Ergebnisse nicht sinnvoll</td>
#       <td>Der Code enthält Fehler, die verhindern, dass er ausgeführt werden kann (z.B. Syntaxfehler) oder es werden Ergebnisse ausgegeben, welche nicht zur Fragestellung passen.</td>
#       <td>0 Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit gravierenden Mängeln</td>
#       <td>Der Code läuft, aber die Ergebnisse sind aufgrund wesentlicher Fehler unvollständig (z.B. fehlende Joins, gravierende Fehler in SQL-Abfragen). Nur geringer Fortschritt erkennbar.</td>
#       <td>25% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit mittleren Mängeln</td>
#       <td>Der Code läuft und liefert teilweise korrekte Ergebnisse, aber es gibt grössere Fehler (z.B. fehlende Spalten, unvollständige SQL-Abfragen). Die Ergebnisse sind nachvollziehbar, aber unvollständig oder ungenau.</td>
#       <td>50% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit minimalen Mängeln</td>
#       <td>Der Code läuft und liefert ein weitgehend korrektes Ergebnis, aber kleinere Fehler (z.B. falsche oder fehlende Sortierung, Rundung von Werten falsch) beeinträchtigen die Vollständigkeit des Ergebnisses.</td>
#       <td>75% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig und korrekt</td>
#       <td>Der Code läuft einwandfrei und liefert das korrekte Ergebnis ohne Mängel.</td>
#       <td>100% der max. erreichbaren Punkte</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### <b>Python Libraries und Settings</b>

# %%
# Libraries
import os
import folium
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/python_postgresql_postgis/OLD Exam

# %% [markdown]
# ## <b>Vorbereitung (Hinweis: dieser Teil wird <u>nicht</u> bewertet)</b>

# %% [markdown]
# #### <b>1.) Starten Sie eine GitHub Codespaces Instanz auf Basis Ihres Forks des folgenden GitHub Repositories:</b>
#
# ##### GitHub-Repository: https://github.com/mario-gellrich-zhaw/python_postgresql_postgis
#
# ##### <span style="color: red;"><b>WICHTIG!!! Verwenden Sie eine GitHub Codespaces Instanz mit ausreichend Arbeitsspeicher (4core, 16GB RAM).</b></span>
#
# <b>Hinweis:</b>
# - Im Unterricht wurden bereits sämtliche Installationen und Einstellungen inkl. der Registrierung des Datenbank Servers auf pgAdmin vorgenommen.
# - Falls Sie die Codespaces-Instanz neu erstellen müssen, folgen Sie bitte den detaillierten Erklärungen auf der README-Seite des GitHub Repositories.

# %% [markdown]
# #### <b>2.) Erstellen und Testen Sie die Datenbankverbindung mit der 'osm_switzerland' Datenbank.</b>

# %%
# Set up Database Connection
user = "pgadmin"
password = "geheim"
host = "localhost"
port = "5432"
database = "osm_switzerland"

# Erstellen der Connection URL
db_connection_url = "postgresql://" + user + ":" + password +\
                    "@" + host + ":" + port + "/" + database

# Erstellen SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Test der Connection
with engine.connect() as connection:
    result = connection.execute(text('SELECT current_database()'))
    print(result.fetchone())

# Verbindung trennen
engine.dispose()
# Out:
# ('osm_switzerland',)

# %% [markdown]
# ## <b>Aufgaben (Dieser Teil wird bewertet!)</b>
# <b>Hinweise zu den folgenden Aufgabenstellungen:</b>
# <ul>
#   <li>In diesem Jupyter Notebook gibt es jeweils zwei Code-Zellen pro Aufgabe:</li>
#   <ol>
#     <li>Eine Codezelle mit Python-Code für die SQL-Abfrage.</li>
#     <li>Eine Codezelle mit Python-Code für die Kartendarstellung der Ergebnisse der jeweiligen SQL-Abfrage.</li>
#   </ol>
#   <li>In den Codezellen für die SQL-Abfrage muss jeweils die SQL-Statement ergänzt werden.</li>
#   <li>In den Codezellen für die Kartendarstellung muss nur dann der Python Code ergänzt werden, wenn in der Aufgabe danach gefragt wird.</li>
# </ul>
# <b style="color:red;">Beachten Sie, dass für die Punktevergabe auch die weiteren Anforderungen zu den Fragen unter 'Details zur Aufgabenstellung' herangezogen werden.</b>

# %% [markdown]
# #### <b>Aufgabe (1): Erstellen Sie eine Abfrage sämtlicher Autoreparatur-Werkstätten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_point'.
# - Stellen sie in der Ergebnistabelle die Spalten: osm_id, shop sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Die Geometry wird mit Hilfe der Funktion st_transform() transformiert, z.B.: *st_transform(p.way, 4326) AS geom*.
# - Tipp: Autoreparatur-Werkstätten sind mit dem key:value Paar shop='car_repair' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.shop,
            st_transform(p.way, 4326) AS geom
        FROM
            planet_osm_point AS p
        WHERE p.shop = 'car_repair';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id        shop                      geom
# 0     7390840334  car_repair  POINT (8.84295 47.25249)
# 1      339573027  car_repair  POINT (8.83413 47.27604)
# 2      339573017  car_repair  POINT (8.83511 47.27619)
# 3      339573018  car_repair  POINT (8.83448 47.27663)
# 4    11240059282  car_repair  POINT (8.84498 47.30095)
# ..           ...         ...                       ...
# 297   5837669721  car_repair   POINT (8.49197 47.4802)
# 298  12247136015  car_repair  POINT (8.68396 47.56527)
# 299  12855181247  car_repair  POINT (8.81851 47.54032)
# 300  12850641833  car_repair  POINT (8.81921 47.54009)
# 301  12855181248  car_repair  POINT (8.81853 47.54027)
#
# [302 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73a6433c4637a4f1cb170f47cc3ef7ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73a6433c4637a4f1cb170f47cc3ef7ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73a6433c4637a4f1cb170f47cc3ef7ea = L.map(
#                 &quot;map_73a6433c4637a4f1cb170f47cc3ef7ea&quot;,
#                 {
#                     center: [47.3917947358392, 8.618542159602649],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1ecb22fd77e509596e7c151b66c66fd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1ecb22fd77e509596e7c151b66c66fd.addTo(map_73a6433c4637a4f1cb170f47cc3ef7ea);
#
#
#
#         function geo_json_db12dfc7545decdb1605102b31269cec_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_db12dfc7545decdb1605102b31269cec = L.geoJson(null, {
#                 onEachFeature: geo_json_db12dfc7545decdb1605102b31269cec_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_db12dfc7545decdb1605102b31269cec_add (data) {
#             geo_json_db12dfc7545decdb1605102b31269cec
#                 .addData(data);
#         }
#             geo_json_db12dfc7545decdb1605102b31269cec_add({&quot;bbox&quot;: [8.375916299999998, 47.19164830012115, 8.9187427, 47.64363020002107], &quot;features&quot;: [{&quot;bbox&quot;: [8.8429547, 47.25249140010813, 8.8429547, 47.25249140010813], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8429547, 47.25249140010813], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 7390840334, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8341296, 47.276036600103026, 8.8341296, 47.276036600103026], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8341296, 47.276036600103026], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 339573027, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8351127, 47.27619100010299, 8.8351127, 47.27619100010299], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8351127, 47.27619100010299], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 339573017, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.834484, 47.276632000102914, 8.834484, 47.276632000102914], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.834484, 47.276632000102914], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 339573018, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8449751, 47.300952600097645, 8.8449751, 47.300952600097645], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8449751, 47.300952600097645], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 11240059282, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8395537, 47.29939390009797, 8.8395537, 47.29939390009797], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8395537, 47.29939390009797], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 10720179451, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.846535, 47.41758040007203, 8.846535, 47.41758040007203], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.846535, 47.41758040007203], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 11053970252, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8467565, 47.41742360007207, 8.8467565, 47.41742360007207], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8467565, 47.41742360007207], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 11053970256, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8458396, 47.439674300067125, 8.8458396, 47.439674300067125], &quot;geometry&q

# %% [markdown]
# #### <b>Aufgabe (2) Erstellen Sie eine Abfrage aller Biergärten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, amenity, name und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Biergärten sind mit dem key:value Paar amenity='biergarten' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.amenity,
            p.name,
            ST_TRANSFORM(p.way::geometry, 4326) AS geom
        FROM planet_osm_point AS p
        WHERE
            p.amenity = 'biergarten';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#        osm_id     amenity            name                      geom
# 0   768907979  biergarten    Engel Lounge  POINT (8.67547 47.23005)
# 1  2679062372  biergarten  Gamschtä Träff  POINT (8.76787 47.23535)
# 2  2518707388  biergarten  zum Adlerhorst  POINT (8.68977 47.38973)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings with popup
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e42610e35eaabe951249b90a14de532c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e42610e35eaabe951249b90a14de532c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e42610e35eaabe951249b90a14de532c = L.map(
#                 &quot;map_e42610e35eaabe951249b90a14de532c&quot;,
#                 {
#                     center: [47.28504446676764, 8.711035866666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e4479880e6e6fc76c914cdcd606ae3a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e4479880e6e6fc76c914cdcd606ae3a.addTo(map_e42610e35eaabe951249b90a14de532c);
#
#
#
#         function geo_json_9e4990dfc5136ec31d576e809dc8f6aa_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_9e4990dfc5136ec31d576e809dc8f6aa = L.geoJson(null, {
#                 onEachFeature: geo_json_9e4990dfc5136ec31d576e809dc8f6aa_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_9e4990dfc5136ec31d576e809dc8f6aa_add (data) {
#             geo_json_9e4990dfc5136ec31d576e809dc8f6aa
#                 .addData(data);
#         }
#             geo_json_9e4990dfc5136ec31d576e809dc8f6aa_add({&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.767871899999998, 47.38973230007818], &quot;features&quot;: [{&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.6754669, 47.23005180011294], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6754669, 47.23005180011294], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Engel Lounge&quot;, &quot;osm_id&quot;: 768907979}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.767871899999998, 47.235349300111814, 8.767871899999998, 47.235349300111814], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.767871899999998, 47.235349300111814], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Gamscht\u00e4 Tr\u00e4ff&quot;, &quot;osm_id&quot;: 2679062372}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.6897688, 47.38973230007818, 8.6897688, 47.38973230007818], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6897688, 47.38973230007818], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;zum Adlerhorst&quot;, &quot;osm_id&quot;: 2518707388}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_9e4990dfc5136ec31d576e809dc8f6aa.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_9e4990dfc5136ec31d576e809dc8f6aa.addTo(map_e42610e35eaabe951249b90a14de532c);
#
#
#             var layer_control_8ee059fac0e7ab2de702577ae6da4052_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_9e4479880e6e6fc76c914cdcd606ae3a,
#                 },
#                 overlays :  {
#                     &quot;map&quot; : geo_json_9e4990dfc5136ec31d576e809dc8f6aa,
#                 },
#             };
#             let layer_control_8ee059fac0e7ab2de702577ae6da4052 = L.control.layers(
#                 layer_control_8ee059fac0e7ab2de702577ae6da4052_layers.base_layers,
#                 layer_control_8ee059fac0e7ab2de702577ae6da4052_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_e42610e35eaabe951249b90a14de532c);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### <b>Aufgabe (3): Erstellen Sie eine Abfrage aller Gebäude in der Stadthausstrasse in Winterthur, welche vollständige Adressangaben besitzen.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_polygon'.
# - Vollständige Adressangabe bedeutet: Strassenname, Haunummer, PLZ, Gemeindename sind vorhanden.
# - Stellen Sie in der Ergebnistabelle sämtliche Adressangaben sowie die transformierte Geometrie als Spalte geom dar.
# - Verwenden Sie für die Darstellung als Hintergrundkarte ein Satellitenbild (ESRIWorldImagery) als maptile.
# - Tipp: Gebäude sind in der Spalte 'building' klassifiziert. Mit *WHERE building IS NOT NULL* können Sie Gebäude filtern.
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p."addr:street",
            p."addr:housenumber",
            p."addr:city",
            p."addr:postcode",
            st_transform(p.way, 4326) AS geom
        FROM
            planet_osm_polygon AS p
        WHERE
            p.building IS NOT NULL
            AND p."addr:street" = 'Stadthausstrasse'
            AND p."addr:housenumber" IS NOT NULL
            AND p."addr:postcode" IS NOT NULL
            AND p."addr:city" = 'Winterthur';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#        osm_id       addr:street addr:housenumber   addr:city addr:postcode  \
# 0     9264543  Stadthausstrasse               4a  Winterthur          8400
# 1    22301937  Stadthausstrasse                4  Winterthur          8400
# 2    75027485  Stadthausstrasse               31  Winterthur          8400
# 3    75027472  Stadthausstrasse               35  Winterthur          8400
# 4    75027503  Stadthausstrasse               37  Winterthur          8400
# ..        ...               ...              ...         ...           ...
# 56   94283231  Stadthausstrasse              145  Winterthur          8400
# 57   94283304  Stadthausstrasse              143  Winterthur          8400
# 58   24804763  Stadthausstrasse               22  Winterthur          8400
# 59   26992511  Stadthausstrasse               24  Winterthur          8400
# 60  134980581  Stadthausstrasse              10b  Winterthur          8400
#
#                                                  geom
# 0   POLYGON ((8.73111 47.50115, 8.73112 47.50085, ...
# 1   POLYGON ((8.73232 47.50109, 8.73233 47.50107, ...
# 2   POLYGON ((8.73162 47.50041, 8.73165 47.50029, ...
# 3   POLYGON ((8.73153 47.5004, 8.73157 47.50026, 8...
# 4   POLYGON ((8.73146 47.5004, 8.73149 47.50028, 8...
# ..                                                ...
# 56  POLYGON ((8.72414 47.4995, 8.72417 47.49939, 8...
# 57  POLYGON ((8.72427 47.49952, 8.72431 47.4994, 8...
# 58  POLYGON ((8.72448 47.49982, 8.72453 47.4997, 8...
# 59  POLYGON ((8.72405 47.49972, 8.72407 47.49967, ...
# 60  POLYGON ((8.72652 47.50075, 8.72661 47.50063, ...
#
# [61 rows x 6 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=17, 
               tiles='ESRIWorldImagery')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8208112cca3057695fdf06f5fbc624a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8208112cca3057695fdf06f5fbc624a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8208112cca3057695fdf06f5fbc624a = L.map(
#                 &quot;map_a8208112cca3057695fdf06f5fbc624a&quot;,
#                 {
#                     center: [47.37707165722384, 8.541184402857143],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62b25566bcd4850f989b42207c548b31 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62b25566bcd4850f989b42207c548b31.addTo(map_a8208112cca3057695fdf06f5fbc624a);
#
#
#             var choropleth_44607fac24df98fb75395289684ca80f = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_99a9e1c7f8a313733e3a4f23ddf47517_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_99a9e1c7f8a313733e3a4f23ddf47517_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_99a9e1c7f8a313733e3a4f23ddf47517 = L.geoJson(null, {
#                 onEachFeature: geo_json_99a9e1c7f8a313733e3a4f23ddf47517_onEachFeature,
#
#                 style: geo_json_99a9e1c7f8a313733e3a4f23ddf47517_styler,
#             ...{
# }
#         });
#
#         function geo_json_99a9e1c7f8a313733e3a4f23ddf47517_add (data) {
#             geo_json_99a9e1c7f8a313733e3a4f23ddf47517
#                 .addData(data);
#         }
#             geo_json_99a9e1c7f8a313733e3a4f23ddf47517_add({&quot;bbox&quot;: [8.5357165, 47.373807500081696, 8.5454687, 47.3806169000802], &quot;features&quot;: [{&quot;bbox&quot;: [8.540159099999999, 47.37773990008085, 8.540159099999999, 47.37773990008085], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540159099999999, 47.37773990008085], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 48.65945843, &quot;name&quot;: &quot;Andr\u00e9 Joe Coiffure&quot;, &quot;osm_id&quot;: 4833061523, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5407058, 47.37708990008098, 8.5407058, 47.37708990008098], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5407058, 47.37708990008098], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 126.93748951, &quot;name&quot;: &quot;Saleh&quot;, &quot;osm_id&quot;: 4424939145, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5399187, 47.376635300081084, 8.5399187, 47.376635300081084], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5399187, 47.376635300081084], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 172.641574, &quot;name&quot;: &quot;Coiffeur Insieme&quot;, &quot;osm_id&quot;: 693318659, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5379091, 47.3779077000808, 8.5379091, 47.3779077000808], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5379091, 47.3779077000808], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 174.98027622, &quot;name&quot;: &quot;McCoiffure&quot;, &quot;osm_id&quot;: 4424939218, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.537875800000002, 47.3774487000809, 8.537875800000002, 47.3774487000809], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.537875800000002, 47.3774487000809], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 192.74767095, &quot;name&quot;: &quot;Art Coiffure Kaiser&quot;, &quot;osm_id&quot;: 4244059289, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.540674899999999, 47.37633050008117, 8.540674899999999, 47.37633050008117], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540674899999999, 47.37633050008117], &quot;type&quot;: &quot;Poin

# %% [markdown]
# #### <b>Aufgabe (4): Erstellen Sie eine Abfrage aller Strassen im Kanton Zürich, welche als 'motorway' klassifiziert sind.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_roads'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, highway und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Motorways sind mit dem key:value Paar highway='motorway' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT 
            p.osm_id,
            p.highway,
            ST_TRANSFORM(p.way::geometry, 4326) AS geom
        FROM public.planet_osm_roads AS p
        WHERE p.highway = 'motorway';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id   highway                                               geom
# 0     546365250  motorway     LINESTRING (8.83096 47.26077, 8.8309 47.26063)
# 1     546365251  motorway    LINESTRING (8.83104 47.26094, 8.83096 47.26077)
# 2      40528299  motorway    LINESTRING (8.83122 47.26097, 8.83134 47.26125)
# 3      40528306  motorway    LINESTRING (8.83116 47.26122, 8.83104 47.26094)
# 4     546365253  motorway  LINESTRING (8.8314 47.2618, 8.83129 47.26153, ...
# ...         ...       ...                                                ...
# 1133  545937136  motorway    LINESTRING (8.72646 47.36173, 8.72631 47.36178)
# 1134  545893926  motorway  LINESTRING (8.70706 47.37128, 8.70653 47.37148...
# 1135  545893931  motorway     LINESTRING (8.70802 47.3708, 8.70835 47.37066)
# 1136  545893927  motorway  LINESTRING (8.7082 47.37082, 8.70769 47.37103,...
# 1137  545893932  motorway  LINESTRING (8.70738 47.37105, 8.7077 47.37093,...
#
# [1138 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    line_weight=3,
    line_color='red'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e5f446246ad8c8468f35520237986ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e5f446246ad8c8468f35520237986ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e5f446246ad8c8468f35520237986ea = L.map(
#                 &quot;map_2e5f446246ad8c8468f35520237986ea&quot;,
#                 {
#                     center: [47.37707165722384, 8.541184402857143],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ba619ac383d205c7c53e7de394ee845 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ba619ac383d205c7c53e7de394ee845.addTo(map_2e5f446246ad8c8468f35520237986ea);
#
#
#             var choropleth_530f3a8ac1d54e518e000e2f2c623db6 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_da505f24df89bdb2519207dd253190ea_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_da505f24df89bdb2519207dd253190ea_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_da505f24df89bdb2519207dd253190ea = L.geoJson(null, {
#                 onEachFeature: geo_json_da505f24df89bdb2519207dd253190ea_onEachFeature,
#
#                 style: geo_json_da505f24df89bdb2519207dd253190ea_styler,
#             ...{
# }
#         });
#
#         function geo_json_da505f24df89bdb2519207dd253190ea_add (data) {
#             geo_json_da505f24df89bdb2519207dd253190ea
#                 .addData(data);
#         }
#             geo_json_da505f24df89bdb2519207dd253190ea_add({&quot;bbox&quot;: [8.5357165, 47.373807500081696, 8.5454687, 47.3806169000802], &quot;features&quot;: [{&quot;bbox&quot;: [8.540159099999999, 47.37773990008085, 8.540159099999999, 47.37773990008085], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540159099999999, 47.37773990008085], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 48.65945843, &quot;name&quot;: &quot;Andr\u00e9 Joe Coiffure&quot;, &quot;osm_id&quot;: 4833061523, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5407058, 47.37708990008098, 8.5407058, 47.37708990008098], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5407058, 47.37708990008098], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 126.93748951, &quot;name&quot;: &quot;Saleh&quot;, &quot;osm_id&quot;: 4424939145, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5399187, 47.376635300081084, 8.5399187, 47.376635300081084], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5399187, 47.376635300081084], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 172.641574, &quot;name&quot;: &quot;Coiffeur Insieme&quot;, &quot;osm_id&quot;: 693318659, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5379091, 47.3779077000808, 8.5379091, 47.3779077000808], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5379091, 47.3779077000808], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 174.98027622, &quot;name&quot;: &quot;McCoiffure&quot;, &quot;osm_id&quot;: 4424939218, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.537875800000002, 47.3774487000809, 8.537875800000002, 47.3774487000809], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.537875800000002, 47.3774487000809], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 192.74767095, &quot;name&quot;: &quot;Art Coiffure Kaiser&quot;, &quot;osm_id&quot;: 4244059289, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.540674899999999, 47.37633050008117, 8.540674899999999, 47.37633050008117], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540674899999999, 47.37633050008117],

# %% [markdown]
# #### <b>Aufgabe (5): Erstellen Sie eine Abfrage aller Flüsse. Generieren Sie zusätzlich Buffer um die Flüsse mit einer Breite von 2000m.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_line'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, waterway sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Flüsse sind mit dem key:value Paar waterway='river' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
# - Tipp: Per Default wird für jedes Fluss-Segment ein separater Buffer erstellt. Es ist nicht notwendig daraus einen einzelnen Buffer zu generieren.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.waterway,
            ST_Transform(ST_Buffer(ST_Transform(p.way::geometry, 3857), 2000), 4326) AS geom
        FROM
            planet_osm_line AS p
        WHERE
            p.waterway = 'river';"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id waterway                                               geom
# 0      33606198    river  POLYGON ((8.8169 47.23988, 8.81692 47.24001, 8...
# 1    1188517700    river  POLYGON ((8.83412 47.2523, 8.8339 47.25261, 8....
# 2      33605947    river  POLYGON ((8.85307 47.27804, 8.85472 47.27888, ...
# 3     315137969    river  POLYGON ((8.88122 47.28055, 8.88198 47.281, 8....
# 4      31109389    river  POLYGON ((8.83416 47.26334, 8.83424 47.26374, ...
# ..          ...      ...                                                ...
# 230    36985639    river  POLYGON ((8.38055 47.41184, 8.38091 47.41384, ...
# 231   106979253    river  POLYGON ((8.1504 47.58325, 8.1497 47.58313, 8....
# 232   151615630    river  POLYGON ((8.61125 47.6655, 8.60905 47.66567, 8...
# 233    12373075    river  POLYGON ((8.59392 47.58207, 8.59251 47.5821, 8...
# 234   833353743    river  POLYGON ((8.76447 47.5801, 8.76203 47.58031, 8...
#
# [235 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d99cbada3317c845f11e93d3f16a139a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d99cbada3317c845f11e93d3f16a139a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d99cbada3317c845f11e93d3f16a139a = L.map(
#                 &quot;map_d99cbada3317c845f11e93d3f16a139a&quot;,
#                 {
#                     center: [47.40838757756123, 8.719786055457108],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4a7e05ad699c9ff761231496bfc6d0a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4a7e05ad699c9ff761231496bfc6d0a.addTo(map_d99cbada3317c845f11e93d3f16a139a);
#
#
#             var choropleth_84fc5b98ac680ecf31d11711e3fdbb56 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_fd6dab63d02ebac96ff36aa9bacc5386_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_fd6dab63d02ebac96ff36aa9bacc5386_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_fd6dab63d02ebac96ff36aa9bacc5386 = L.geoJson(null, {
#                 onEachFeature: geo_json_fd6dab63d02ebac96ff36aa9bacc5386_onEachFeature,
#
#                 style: geo_json_fd6dab63d02ebac96ff36aa9bacc5386_styler,
#             ...{
# }
#         });
#
#         function geo_json_fd6dab63d02ebac96ff36aa9bacc5386_add (data) {
#             geo_json_fd6dab63d02ebac96ff36aa9bacc5386
#                 .addData(data);
#         }
#             geo_json_fd6dab63d02ebac96ff36aa9bacc5386_add({&quot;bbox&quot;: [8.128864778071952, 47.15464847188619, 8.978196660233557, 47.7076709834925], &quot;features&quot;: [{&quot;bbox&quot;: [8.816545209838738, 47.224576110663506, 8.872824195379561, 47.25428907712454], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.81690326211776, 47.239879159068536], [8.816921504049507, 47.24001426920485], [8.81713687587517, 47.24108499457087], [8.817163575875169, 47.24118459046493], [8.818181939488614, 47.24357053568551], [8.818236639488616, 47.243662427758345], [8.819249431498152, 47.2450893294445], [8.819322531498152, 47.24517721949498], [8.820823092219674, 47.246701185005925], [8.82264315013953, 47.248055235175265], [8.82272705013953, 47.24810892617959], [8.826070150503584, 47.249797466844626], [8.826163550503582, 47.2498340595469], [8.828017923812645, 47.2503858307993], [8.828329238669111, 47.2505964145671], [8.82854593866911, 47.250728891899776], [8.83044924623369, 47.25174354636496], [8.830711546233692, 47.251864923271114], [8.831832029970036, 47.2523433526663], [8.832185529970033, 47.25248222498883], [8.83377209841624, 47.25303603473671], [8.834041998416241, 47.25311901733018], [8.835991618913908, 47.25362795646517], [8.836268018913911, 47.25368784332753], [8.839401618070303, 47.25416239047699], [8.839671918070302, 47.25418638499816], [8.84143922721246, 47.254283378436206], [8.84170722721246, 47.25428907712454], [8.844492651088627, 47.25420136302351], [8.844765551088626, 47.25417826830095], [8.84739111142346, 47.25381953229715], [8.847666511423464, 47.2537671439136], [8.849564182763539, 47.25332727016329], [8.849850682763538, 47.25324848697785], [8.850601931419487, 47.25301876516377], [8.853522221986392, 47.25337043723881], [8.857043474908522, 47.25332081334431], [8.860482804916428, 47.25280585910443], [8.863708040486708, 47.251845350806256], [8.866595237625129, 47.250476177304584], [8.869033442964819, 47.24875092589623], [8.870928957641937, 47.246735865876204], [8.872208938090456, 47.244508406587826], [8.872824195379561, 47.242154126931055], [8.872751085516674, 47.23976348982733], [8.871992418072823, 47.23742836741324], [8.870577348212413, 47.23523851024902], [8.868560256276593, 47.23327809625827], [8.866018657977262, 47.23162249232507], [8.863050225511723, 47.230335353530194], [8.859769034074901, 47.22946617217958], [8.859745386987704, 47.22946166287566], [8.859722984538712, 47.22945319733071], [8.858606575938033, 47.22906533329031], [8.857988575938036, 47.22886879232079], [8.857360533220522, 47.22867891950819], [8.857000733220522, 47.22857569762167], [8.854686383077851, 47.22803464842928], [8.854323683077851, 47.22796823366931]

# %% [markdown]
# #### <b>Aufgabe (6): Erstellen Sie eine Abfrage der Bäckerei-Geschäfte in Zürich und Winterthur.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point' (Backereien).
# - Verwenden Sie die Städtenamen aus den Adressangaben für die Abfrage der Bäckerei-Standorte (Zürich, Winterthur).
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, "addr:city" sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Sortieren Sie die Bäckerei-Geschäfte aufsteigend nach osm_id.
# - Tipp: Bäckerei-Geschäfte sind mit dem key:value Paar shop='bakery' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            h.osm_id,
            h.shop,
            h.name,
            h."addr:city",
            ST_Transform(h.way, 4326) AS geom
        FROM planet_osm_point h
        WHERE h.shop = 'bakery'
        AND h."addr:city" IN ('Zürich', 'Winterthur')
        ORDER BY h.osm_id ASC;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id    shop                  name addr:city  \
# 0      252457457  bakery  Steiner Flughafebeck    Zürich
# 1      266630770  bakery           Brezelkönig    Zürich
# 2      267879346  bakery       Walter Buchmann    Zürich
# 3      268602152  bakery               Moser's    Zürich
# 4      270794699  bakery            John Baker    Zürich
# ..           ...     ...                   ...       ...
# 102  10884168277  bakery              Juliette    Zürich
# 103  10946043353  bakery         Babu's Bakery    Zürich
# 104  10955852823  bakery          Täglich Brot    Zürich
# 105  11951988149  bakery                Wagner    Zürich
# 106  12368630564  bakery                 Tsugi    Zürich
#
#                          geom
# 0    POINT (8.49779 47.40311)
# 1    POINT (8.48875 47.39147)
# 2     POINT (8.5191 47.36258)
# 3     POINT (8.54945 47.3632)
# 4    POINT (8.56645 47.36493)
# ..                        ...
# 102   POINT (8.5328 47.36658)
# 103  POINT (8.51568 47.37473)
# 104  POINT (8.50705 47.36079)
# 105   POINT (8.51763 47.3698)
# 106   POINT (8.53092 47.3933)
#
# [107 rows x 5 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=12, 
               tiles='EsriWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c08191a9339fe1d53320d2d44619b3e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c08191a9339fe1d53320d2d44619b3e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c08191a9339fe1d53320d2d44619b3e1 = L.map(
#                 &quot;map_c08191a9339fe1d53320d2d44619b3e1&quot;,
#                 {
#                     center: [47.39487878605834, 8.555985045794392],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9600f7c46853dd3def32bf8e4ce72b98 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9600f7c46853dd3def32bf8e4ce72b98.addTo(map_c08191a9339fe1d53320d2d44619b3e1);
#
#
#
#         function geo_json_4c3135a53c90b1c2ff7fdbecb38792a0_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4c3135a53c90b1c2ff7fdbecb38792a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_4c3135a53c90b1c2ff7fdbecb38792a0_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_4c3135a53c90b1c2ff7fdbecb38792a0_add (data) {
#             geo_json_4c3135a53c90b1c2ff7fdbecb38792a0
#                 .addData(data);
#         }
#             geo_json_4c3135a53c90b1c2ff7fdbecb38792a0_add({&quot;bbox&quot;: [8.481048199999998, 47.33904520008934, 8.7625839, 47.51028540005134], &quot;features&quot;: [{&quot;bbox&quot;: [8.497792, 47.40310610007525, 8.497792, 47.40310610007525], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.497792, 47.40310610007525], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Steiner Flughafebeck&quot;, &quot;osm_id&quot;: 252457457, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.4887528, 47.3914676000778, 8.4887528, 47.3914676000778], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.4887528, 47.3914676000778], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Brezelk\u00f6nig&quot;, &quot;osm_id&quot;: 266630770, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5191037, 47.36258390008416, 8.5191037, 47.36258390008416], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5191037, 47.36258390008416], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Walter Buchmann&quot;, &quot;osm_id&quot;: 267879346, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5494522, 47.36320120008403, 8.5494522, 47.36320120008403], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5494522, 47.36320120008403], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Moser\u0027s&quot;, &quot;osm_id&quot;: 268602152, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5664519, 47.36492500008365, 8.5664519, 47.36492500008365], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5664519, 47.36492500008365], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;John Baker&quot;, &quot;osm_id&quot;: 270794699, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5540543, 47.369558800082636, 8.5540543, 47.369558800082636], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5540543, 47.369558800082636], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Caf\u00e9 Berner&quot;, &quot;osm_id&quot;: 270799257, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7313948, 47.49943290005378, 8.7313948, 47.49943290005378], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7313948, 47.49943290005378], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;name&quot;: &quot;Grabe-Beck&quot;,

# %% [markdown]
# #### <b>Aufgabe (7): Erstellen Sie eine Abfrage sämtlicher Coiffeur-Geschäfte in einem Radius von 500m um den Hauptbahnhof in Zürich.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die Daten in der Tabelle 'planet_osm_point'.
# - Berechnen Sie in der Abfrage die Distanz jedes Coiffeur-Geschäfts zum Hauptbahnhof in Metern als Spalte 'distance_meters'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, distance_meters, sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Integrieren Sie in die Kartendarstellung den Namen (Spalte 'name') der Coiffeur-Geschäfte als Popup.
# - Tipp: Coiffeur-Geschäfte sind mit dem key:value Paar shop='hairdresser' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
            p.osm_id,
            p.shop,
            p.name,
            ST_Distance(
                ST_Transform(p.way, 4326)::geography,
                ST_SetSRID(ST_MakePoint(8.540192, 47.378177), 4326)::geography
            ) AS distance_meters,
            ST_TRANSFORM(p.way, 4326) AS geom
        FROM
            planet_osm_point AS p
        WHERE
            p.shop = 'hairdresser'
            AND ST_DWithin(
                ST_Transform(p.way, 4326)::geography,
                ST_SetSRID(ST_MakePoint(8.540192, 47.378177), 4326)::geography,
                500
            )
        ORDER BY distance_meters;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#        osm_id         shop                 name  distance_meters  \
# 0  4833061523  hairdresser   André Joe Coiffure        48.659458
# 1  4424939145  hairdresser                Saleh       126.937490
# 2   693318659  hairdresser     Coiffeur Insieme       172.641574
# 3  4424939218  hairdresser           McCoiffure       174.980276
# 4  4244059289  hairdresser  Art Coiffure Kaiser       192.747671
#
#                        geom
# 0  POINT (8.54016 47.37774)
# 1  POINT (8.54071 47.37709)
# 2  POINT (8.53992 47.37664)
# 3  POINT (8.53791 47.37791)
# 4  POINT (8.53788 47.37745)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=16, 
               tiles='EsriWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
    popup=folium.GeoJsonPopup(fields=['name'])
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5aa13427332c0067d176c3092728503 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5aa13427332c0067d176c3092728503&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5aa13427332c0067d176c3092728503 = L.map(
#                 &quot;map_e5aa13427332c0067d176c3092728503&quot;,
#                 {
#                     center: [47.37707165722384, 8.541184402857143],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4460c656f26fd93e05a9c0442d64bbce = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4460c656f26fd93e05a9c0442d64bbce.addTo(map_e5aa13427332c0067d176c3092728503);
#
#
#
#         function geo_json_b3ab772cf3ca1cca728247553a357cae_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b3ab772cf3ca1cca728247553a357cae = L.geoJson(null, {
#                 onEachFeature: geo_json_b3ab772cf3ca1cca728247553a357cae_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_b3ab772cf3ca1cca728247553a357cae_add (data) {
#             geo_json_b3ab772cf3ca1cca728247553a357cae
#                 .addData(data);
#         }
#             geo_json_b3ab772cf3ca1cca728247553a357cae_add({&quot;bbox&quot;: [8.5357165, 47.373807500081696, 8.5454687, 47.3806169000802], &quot;features&quot;: [{&quot;bbox&quot;: [8.540159099999999, 47.37773990008085, 8.540159099999999, 47.37773990008085], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540159099999999, 47.37773990008085], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 48.65945843, &quot;name&quot;: &quot;Andr\u00e9 Joe Coiffure&quot;, &quot;osm_id&quot;: 4833061523, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5407058, 47.37708990008098, 8.5407058, 47.37708990008098], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5407058, 47.37708990008098], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 126.93748951, &quot;name&quot;: &quot;Saleh&quot;, &quot;osm_id&quot;: 4424939145, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5399187, 47.376635300081084, 8.5399187, 47.376635300081084], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5399187, 47.376635300081084], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 172.641574, &quot;name&quot;: &quot;Coiffeur Insieme&quot;, &quot;osm_id&quot;: 693318659, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5379091, 47.3779077000808, 8.5379091, 47.3779077000808], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5379091, 47.3779077000808], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 174.98027622, &quot;name&quot;: &quot;McCoiffure&quot;, &quot;osm_id&quot;: 4424939218, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.537875800000002, 47.3774487000809, 8.537875800000002, 47.3774487000809], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.537875800000002, 47.3774487000809], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;distance_meters&quot;: 192.74767095, &quot;name&quot;: &quot;Art Coiffure Kaiser&quot;, &quot;osm_id&quot;: 4244059289, &quot;shop&quot;: &quot;hairdresser&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.540674899999999, 47.37633050008117, 8.540674899999999, 47.37633050008117], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.540674899999999, 47.37633050008117], &quot;type&quot;: &quot;Point&qu

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('IP Address:', socket.gethostbyname(socket.gethostname()))
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-10-05 12:29:10
# Python Version: 3.12.1
# IP Address: 127.0.0.1
# -----------------------------------
